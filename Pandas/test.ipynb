# %%
import pandas as pd

# %%
df_data= pd.read_excel("E:\\Company's\\AXION\\Sooraj Singh JadonTask 1..xlsx")
df_data.head()
# Out:
#     Primary Key Order Date Product Category  \
# 0   SO0026296-1 2023-03-08           SPRAYS
# 1   SO0026385-1 2023-03-08           SPRAYS
# 2  SO0026385-11 2023-03-08           SPRAYS
# 3   SO0028352-1 2023-03-08           SPRAYS
# 4   SO0028770-1 2023-03-08           SPRAYS
#
#                                            Complaint  \
# 0  VISIBLY NOTICE fasteners under cab on P clips ...
# 1                       Fuel door will not stay open
# 2   Compressor pressure line, braided steel, crushed
# 3                 Oil running from bottom of machine
# 4                   MISSING VECTOR & INTRIP UNLOCKS.
#
#                                                Cause  Cause Keyword  \
# 0                            Not tighten at factory.  Not Tightened
# 1     GAS STRUT NOT INSTALLED OR ANYWHERE ON MACHINE  Not Installed
# 2  Compressor pressure line, braided steel, crush...  Not Mentioned
# 3  OIL RETURN UNDER MACHINE SWIVEL FITTING LEFT L...       Loosened
# ...

# %%
dt_vis=df_data.groupby(['Product Category','Cause Keyword']).agg(
    total_problems=('Primary Key','count')
).reset_index()
dt_vis
# Out:
#    Product Category         Cause Keyword  total_problems
# 0             BALER                 Fault               1
# 1             BALER   Screwed in a Thread               1
# 2            SPRAYS                 Blown               1
# 3            SPRAYS        Failed Sending               1
# 4            SPRAYS                 Fault               1
# 5            SPRAYS        Internal Issue               1
# 6            SPRAYS               Leaking               2
# 7            SPRAYS              Loosened               1
# 8            SPRAYS  Lubricant Drip Drown               1
# 9            SPRAYS              No Oring               1
# 10           SPRAYS          Not Included               1
# 11           SPRAYS         Not Installed               2
# 12           SPRAYS         Not Mentioned               1
# 13           SPRAYS           Not Tighten               1
# 14           SPRAYS         Not Tightened               1
# ...
